# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv',low_memory=False)

# %%
pd.set_option("display.max_columns",200)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df.describe()
# Out:
#          ResponseId       WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  49191.000000  42893.000000  43042.000000   35975.000000   35975.000000
# mean   24596.000000     13.367403     16.570861       7.867352       4.104211
# std    14200.362883     10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000      1.000000       1.000000       1.000000
# 25%    12298.500000      5.000000      8.000000       7.000000       2.000000
# 50%    24596.000000     10.000000     14.000000       9.000000       4.000000
# 75%    36893.500000     20.000000     24.000000       9.000000       6.000000
# max    49191.000000    100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# ...

# %%
df["ConvertedCompYearly"].count()
# Out:
# np.int64(23947)

# %%
df["ConvertedCompYearly"].median()
# Out:
# np.float64(75320.0)

# %%
df["ConvertedCompYearly"].mean()
# Out:
# np.float64(101761.53990061386)

# %%
df["LearnCodeChoose"].value_counts()
# Out:
# LearnCodeChoose
# Yes, I am not new to coding but am learning new coding techniques or programming language      32362
# No, I am not new to coding and did not learn new coding techniques or programming languages    12501
# Yes, I am new to coding or currently a student                                                  1995
# Name: count, dtype: int64

# %%
df1=pd.read_csv("survey_results_schema.csv",low_memory=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   qid       139 non-null    object
#  1   qname     139 non-null    object
#  2   question  139 non-null    object
#  3   type      139 non-null    object
#  4   sub       49 non-null     object
#  5   sq_id     49 non-null     float64
# dtypes: float64(1), object(5)
# memory usage: 6.6+ KB

# %%
pd.set_option("display.max_columns",150)
pd.set_option("display.max_rows",150)

# %%
df1.set_index("qname",inplace=True)

# %%
df1.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
df1.loc['LearnCodeChoose','question']
# Out:
# 'Did you begin learning to code or learn a new coding skill/programming language in the last year?'

# %%
df[df["Country"]=="India"]["Industry"].value_counts(normalize=True)
# Out:
# Industry
# Software Development                          0.678086
# Fintech                                       0.054408
# Banking/Financial Services                    0.038791
# Other:                                        0.038287
# Internet, Telecomm or Information Services    0.038287
# Healthcare                                    0.027204
# Manufacturing                                 0.022166
# Computer Systems Design and Services          0.018640
# Retail and Consumer Services                  0.017632
# Transportation, or Supply Chain               0.017128
# Media & Advertising Services                  0.012594
# Government                                    0.012091
# Higher Education                              0.011083
# Energy                                        0.007557
# Insurance                                     0.006045
# Name: proportion, dtype: float64

# %%
country_grp=df.groupby(["Country"])

# %%
country_grp.get_group(("India",))
# Out:
#        ResponseId                      MainBranch              Age  \
# 13             14  I am a developer by profession  25-34 years old
# 15             16  I am a developer by profession  18-24 years old
# 46             47  I am a developer by profession  35-44 years old
# 90             91  I am a developer by profession  25-34 years old
# 133           134  I am a developer by profession  25-34 years old
# ...           ...                             ...              ...
# 49132       49133     I code primarily as a hobby  25-34 years old
# 49141       49142  I am a developer by profession  18-24 years old
# 49149       49150  I am a developer by profession  25-34 years old
# 49154       49155  I am a developer by profession  45-54 years old
# 49155       49156  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 13          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
print(country_grp.groups.keys())
# Out:
# dict_keys(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Chile', 'China', 'Colombia', 'Congo, Republic of the...', 'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic', "Côte d'Ivoire", "Democratic People's Republic of Korea", 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Estonia', 'Ethiopia', 'Fiji', 'Finland', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong (S.A.R.)', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran, Islamic Republic of...', 'Iraq', 'Ireland', 'Isle of Ma
# ...

# %%
country_grp["Industry"].value_counts(normalize=True).loc["India"]
# Out:
# Country      Industry
# Afghanistan  Software Development            0.625000
#              Energy                          0.125000
#              Media & Advertising Services    0.125000
#              Other:                          0.125000
# Albania      Software Development            0.850000
#                                                ...
# Zimbabwe     Banking/Financial Services      0.181818
#              Fintech                         0.090909
#              Manufacturing                   0.090909
#              Media & Advertising Services    0.090909
#              Retail and Consumer Services    0.090909
# Name: proportion, Length: 1373, dtype: float64

# %%
country_grp["ConvertedCompYearly"].median().loc["India"]
# Out:
# np.float64(17029.0)

# %%
country_grp["ConvertedCompYearly"].agg(["median","mean"]).loc["India"]
# Out:
# median    17029.000000
# mean      44291.789234
# Name: India, dtype: float64

# %%
country_grp["LanguageHaveWorkedWith"].apply(lambda x: (x.str.contains("Python",na=False)).value_counts(normalize=True))
# Out:
# Country
# Afghanistan  False    0.692308
#              True     0.307692
# Albania      False    0.545455
#              True     0.454545
# Algeria      False    0.530612
#                         ...
# Yemen        True     0.333333
# Zambia       True     0.538462
#              False    0.461538
# Zimbabwe     True     0.538462
#              False    0.461538
# Name: LanguageHaveWorkedWith, Length: 332, dtype: float64

# %%
total_respondant=df["Country"].value_counts()
total_respondant
# Out:
# Country
# United States of America                                7233
# Germany                                                 3025
# India                                                   2547
# United Kingdom of Great Britain and Northern Ireland    2042
# France                                                  1409
#                                                         ...
# Lesotho                                                    1
# Djibouti                                                   1
# Cape Verde                                                 1
# Palau                                                      1
# Guinea                                                     1
# Name: count, Length: 177, dtype: int64

# %%
python_knowers=country_grp["LanguageHaveWorkedWith"].apply(lambda x: (x.str.contains("Python",na=False)).sum())
python_knowers
# Out:
# Country
# Afghanistan                              4
# Albania                                 10
# Algeria                                 23
# Andorra                                  2
# Angola                                   1
#                                         ..
# Venezuela, Bolivarian Republic of...    23
# Viet Nam                                78
# Yemen                                    6
# Zambia                                   7
# Zimbabwe                                 7
# Name: LanguageHaveWorkedWith, Length: 177, dtype: int64

# %%
df_py=pd.concat([python_knowers,total_respondant],axis=1,sort=False)
df_py
# Out:
#                                       LanguageHaveWorkedWith  count
# Country
# Afghanistan                                                4     13
# Albania                                                   10     22
# Algeria                                                   23     49
# Andorra                                                    2      6
# Angola                                                     1      7
# ...                                                      ...    ...
# Venezuela, Bolivarian Republic of...                      23     47
# Viet Nam                                                  78    145
# Yemen                                                      6     18
# Zambia                                                     7     13
# Zimbabwe                                                   7     13
#
# [177 rows x 2 columns]

# %%
df_py["pct_python"]=df_py["LanguageHaveWorkedWith"]/df_py["count"]*100

# %%
df_py
# Out:
#                                       LanguageHaveWorkedWith  count  \
# Country
# Afghanistan                                                4     13
# Albania                                                   10     22
# Algeria                                                   23     49
# Andorra                                                    2      6
# Angola                                                     1      7
# ...                                                      ...    ...
# Venezuela, Bolivarian Republic of...                      23     47
# Viet Nam                                                  78    145
# Yemen                                                      6     18
# Zambia                                                     7     13
# Zimbabwe                                                   7     13
#
#                                       pct_python
# Country
# Afghanistan                            30.769231
# ...

# %%
df_py.rename(columns={"LanguageHaveWorkedWith":"Py_knowers","count":"total_peeps"},inplace=True)
df_py
# Out:
#                                       Py_knowers  total_peeps  pct_python
# Country
# Afghanistan                                    4           13   30.769231
# Albania                                       10           22   45.454545
# Algeria                                       23           49   46.938776
# Andorra                                        2            6   33.333333
# Angola                                         1            7   14.285714
# ...                                          ...          ...         ...
# Venezuela, Bolivarian Republic of...          23           47   48.936170
# Viet Nam                                      78          145   53.793103
# Yemen                                          6           18   33.333333
# Zambia                                         7           13   53.846154
# Zimbabwe                                       7           13   53.846154
#
# [177 rows x 3 columns]

# %%
df_py.sort_values(by=["pct_python"],ascending=False).head(50)
# Out:
#                                        Py_knowers  total_peeps  pct_python
# Country
# Cape Verde                                      1            1  100.000000
# Lesotho                                         1            1  100.000000
# Mali                                            2            2  100.000000
# Niger                                           1            1  100.000000
# Mongolia                                        3            3  100.000000
# Guinea                                          1            1  100.000000
# Palau                                           1            1  100.000000
# Suriname                                        2            2  100.000000
# Saint Lucia                                     2            2  100.000000
# Haiti                                           2            2  100.000000
# Guinea-Bissau                                   1            1  100.000000
# ...

# %%
df_py.loc["India"]
# Out:
# Py_knowers     1162.000000
# total_peeps    2547.000000
# pct_python       45.622301
# Name: India, dtype: float64
