# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv',low_memory=False)

# %%
#df

# %%
df.shape
df.isnull().sum().sum()
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), object(119)
# memory usage: 64.6+ MB

# %%
pd.set_option('display.max_columns',172)
pd.set_option('display.max_rows',172)

# %%
schema_df=pd.read_csv('survey_results_schema.csv',index_col='qname')

# %%
#schema_df.sort_index()

# %%
#df.head(10)

# %%
#df.tail(10)

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed                                                33750
# Independent contractor, freelancer, or self-employed     6708
# Student                                                  4428
# Not employed                                             2227
# Retired                                                   708
# I prefer not to say                                       518
# Name: count, dtype: int64

# %%
df.loc[0:5,'ResponseId':'Employment']
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
# 5           6  I am a developer by profession  45-54 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment
# 0                                           Employed
# ...

# %%
#df.set_index('ResponseId',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
schema_df.loc['ICorPM','question']
# Out:
# 'Are you an individual contributor or people manager?'

# %%
#df

# %%
df[df['YearsCode']>10].head()
# Out:
#    index  ResponseId                      MainBranch              Age  \
# 0      0           1  I am a developer by profession  25-34 years old
# 2      2           3  I am a developer by profession  35-44 years old
# 4      4           5  I am a developer by profession  35-44 years old
# 5      5           6  I am a developer by profession  45-54 years old
# 6      6           7  I am a developer by profession  25-34 years old
#
#                                              EdLevel  \
# 0    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 6  Some college/university study without earning ...
#
#                                           Employment  \
# 0                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 4  Independent contractor, freelancer, or self-em...
# ...

# %%
ind=['Fintech','Insurance']

# %%
df.loc[df['Industry'].isin(ind),['ResponseId','Industry']].head()
# Out:
#     ResponseId   Industry
# 0            1    Fintech
# 5            6    Fintech
# 6            7  Insurance
# 10          11    Fintech
# 11          12    Fintech

# %%
df.loc[df['EdLevel'].str.contains('M.A.',na=False),['ResponseId','EdLevel']].head()
# Out:
#     ResponseId                                          EdLevel
# 0            1  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4            5  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5            6  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9           10  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 10          11  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)

# %%
df.rename(columns={'EdLevel':'EduLevel'},inplace=True)

# %%
#df

# %%
df['Country']=df['Country'].str.lower()

# %%
df['WorkExp'].apply(lambda x:x*2)
# Out:
# 0        16.0
# 1         4.0
# 2        20.0
# 3         8.0
# 4        42.0
#          ...
# 49186     NaN
# 49187    50.0
# 49188    34.0
# 49189     4.0
# 49190     NaN
# Name: WorkExp, Length: 49191, dtype: float64

# %%
#df.applymap(type)

# %%
df['Country']=df['Country'].replace({'India':'Ind'})

# %%
df['Country'].head(20)
# Out:
# 0         ukraine
# 1     netherlands
# 2         ukraine
# 3         ukraine
# 4         ukraine
# 5         ukraine
# 6         ukraine
# 7         ukraine
# 8         ukraine
# 9         ukraine
# 10        ukraine
# 11        ukraine
# 12        ukraine
# 13          india
# 14        georgia
# 15          india
# 16      australia
# 17         greece
# 18        germany
# 19     bangladesh
# Name: Country, dtype: object

# %%
#df['Country']=df['Country'].map({'Ind':'india'})

# %%
df['Country'].head(20)
# Out:
# 0         ukraine
# 1     netherlands
# 2         ukraine
# 3         ukraine
# 4         ukraine
# 5         ukraine
# 6         ukraine
# 7         ukraine
# 8         ukraine
# 9         ukraine
# 10        ukraine
# 11        ukraine
# 12        ukraine
# 13          india
# 14        georgia
# 15          india
# 16      australia
# 17         greece
# 18        germany
# 19     bangladesh
# Name: Country, dtype: object

# %%
df['Random']=df['YearsCode']+df['WorkExp']

# %%
df.drop(columns="Random")
# Out:
#        index  ResponseId                                         MainBranch  \
# 0          0           1                     I am a developer by profession
# 1          1           2                     I am a developer by profession
# 2          2           3                     I am a developer by profession
# 3          3           4                     I am a developer by profession
# 4          4           5                     I am a developer by profession
# ...      ...         ...                                                ...
# 49186  49186       49187                        I code primarily as a hobby
# 49187  49187       49188                     I am a developer by profession
# 49188  49188       49189                     I am a developer by profession
# 49189  49189       49190                     I am a developer by profession
# 49190  49190       49191  I am not primarily a developer, but I write co...
#
# ...

# %%
df.drop(index=0)
# Out:
#        index  ResponseId                                         MainBranch  \
# 1          1           2                     I am a developer by profession
# 2          2           3                     I am a developer by profession
# 3          3           4                     I am a developer by profession
# 4          4           5                     I am a developer by profession
# 5          5           6                     I am a developer by profession
# ...      ...         ...                                                ...
# 49186  49186       49187                        I code primarily as a hobby
# 49187  49187       49188                     I am a developer by profession
# 49188  49188       49189                     I am a developer by profession
# 49189  49189       49190                     I am a developer by profession
# 49190  49190       49191  I am not primarily a developer, but I write co...
#
# ...

# %%
cleaned_rows = pd.DataFrame([
    {'Age': '20 years old', 'Country': 'India'}
])

# %%
df = pd.concat([df, cleaned_rows], ignore_index=True)

# %%
#df

# %%
df.sort_values(by=["Country","CompTotal"], ascending=[True,False])
# Out:
#          index  ResponseId                                         MainBranch  \
# 49191      NaN         NaN                                                NaN
# 40306  40306.0     40307.0                     I am a developer by profession
# 7076    7076.0      7077.0  I am not primarily a developer, but I write co...
# 45924  45924.0     45925.0                     I am a developer by profession
# 6009    6009.0      6010.0                     I am a developer by profession
# ...        ...         ...                                                ...
# 49185  49185.0     49186.0                     I am a developer by profession
# 49186  49186.0     49187.0                        I code primarily as a hobby
# 49187  49187.0     49188.0                     I am a developer by profession
# 49189  49189.0     49190.0                     I am a developer by profession
# 49190  49190.0     49191.0  I am not primarily a developer, but I write co...
#
# ...

# %%
df["CompTotal"].nlargest(24500)
# Out:
# 4933     5.555556e+74
# 44526    8.000000e+23
# 35764    1.000000e+23
# 28545    9.223372e+18
# 22732    1.000000e+17
#              ...
# 21194    0.000000e+00
# 21296    0.000000e+00
# 21370    0.000000e+00
# 21380    0.000000e+00
# 21425    0.000000e+00
# Name: CompTotal, Length: 24500, dtype: float64

# %%
df.head()
# Out:
#    index  ResponseId                      MainBranch              Age  \
# 0    0.0         1.0  I am a developer by profession  25-34 years old
# 1    1.0         2.0  I am a developer by profession  25-34 years old
# 2    2.0         3.0  I am a developer by profession  35-44 years old
# 3    3.0         4.0  I am a developer by profession  35-44 years old
# 4    4.0         5.0  I am a developer by profession  35-44 years old
#
#                                           EduLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# ...

# %%
pd.set_option('display.max_columns', 8)
df.head()
# Out:
#    index  ResponseId                      MainBranch              Age  ...  \
# 0    0.0         1.0  I am a developer by profession  25-34 years old  ...
# 1    1.0         2.0  I am a developer by profession  25-34 years old  ...
# 2    2.0         3.0  I am a developer by profession  35-44 years old  ...
# 3    3.0         4.0  I am a developer by profession  35-44 years old  ...
# 4    4.0         5.0  I am a developer by profession  35-44 years old  ...
#
#                                               AIOpen ConvertedCompYearly  \
# 0              Troubleshooting, profiling, debugging             61256.0
# 1                          All skills. AI is a flop.            104413.0
# 2  Understand how things actually work, problem s...             53061.0
# 3                                                NaN             36197.0
# 4  critical thinking, the skill to define the tas...             60000.0
#
#   JobSat  Random
# 0   10.0    22.0
# 1    9.0    12.0
# 2    8.0    22.0
# ...

# %%
df.head()
# Out:
#    index  ResponseId                      MainBranch              Age  ...  \
# 0    0.0         1.0  I am a developer by profession  25-34 years old  ...
# 1    1.0         2.0  I am a developer by profession  25-34 years old  ...
# 2    2.0         3.0  I am a developer by profession  35-44 years old  ...
# 3    3.0         4.0  I am a developer by profession  35-44 years old  ...
# 4    4.0         5.0  I am a developer by profession  35-44 years old  ...
#
#                                               AIOpen ConvertedCompYearly  \
# 0              Troubleshooting, profiling, debugging             61256.0
# 1                          All skills. AI is a flop.            104413.0
# 2  Understand how things actually work, problem s...             53061.0
# 3                                                NaN             36197.0
# 4  critical thinking, the skill to define the tas...             60000.0
#
#   JobSat  Random
# 0   10.0    22.0
# 1    9.0    12.0
# 2    8.0    22.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(x='YearsCode',y='ConvertedCompYearly',data=df)
plt.yscale('log')
plt.show()

# %%
sns.boxplot(df['ConvertedCompYearly'])
plt.yscale('log')
plt.show()
