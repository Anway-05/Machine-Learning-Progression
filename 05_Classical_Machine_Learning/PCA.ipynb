# %%
import pandas as pd

# %%
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder as ohe
from sklearn.preprocessing import StandardScaler as ss
from sklearn.compose import ColumnTransformer as ct
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.model_selection import train_test_split as tts

# %%
c=ct([("numeric",ss(),["Age","RestingBP","Cholesterol","MaxHR","Oldpeak"]),
      ("categorical",ohe(drop="first"),["Sex","ChestPainType","RestingECG","ExerciseAngina","ST_Slope"])],remainder="passthrough")

# %%
p=Pipeline([("transformer",c),("model",rfc(n_estimators=20))])

# %%
x=df.drop(["HeartDisease"],axis=1)
y=df["HeartDisease"]

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=18)

# %%
p.fit(x_train,y_train)
p.score(x_test,y_test)
# Out:
# 0.8369565217391305

# %%
from sklearn.decomposition import PCA

# %%
p1=Pipeline([("transformer",c),("pca",PCA(0.95)),("model",rfc(n_estimators=20))])

# %%
p1.fit(x_train,y_train)
p1.score(x_test,y_test)
# Out:
# 0.8206521739130435
