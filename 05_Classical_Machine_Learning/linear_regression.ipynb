# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(data=df,x="area",y="price")
plt.show()
# sns.scatterplot(data=df,x="area",y="price")

# %%
new_df=df.drop('price',axis='columns')
prices=df["price"]

# %%
reg=linear_model.LinearRegression()
reg.fit(new_df,prices)
# Out:
# LinearRegression()

# %%
reg.predict(pd.DataFrame({'area':[3500,5500,7000]}))
# Out:
# array([ 655873.28767123,  927448.63013699, 1131130.1369863 ])

# %%
reg.predict(new_df[["area"]])
# Out:
# array([533664.38356164, 587979.45205479, 615136.98630137, 669452.05479452,
#        723767.12328767])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
test_df=pd.read_csv("areas.csv")
test_df
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
#test_df["price"]=reg.predict(test_df)
test_df
# Out:
#     area         price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
test_df.to_csv("prediction.csv")

# %%
plt.scatter(data=df,x="area",y="price",color="red")
plt.plot(df.area,reg.predict(df[["area"]]),color="blue")
plt.show()

# %%
exer_df=pd.read_csv("canada_per_capita_income.csv")
exer_df_new=exer_df.drop("per capita income (US$)",axis="columns")
income=exer_df["per capita income (US$)"]

# %%
new_reg=linear_model.LinearRegression()
new_reg.fit(exer_df_new,income)
# Out:
# LinearRegression()

# %%
new_reg.predict(pd.DataFrame({"year":[2018,2020,2022,2024,2026]}))
# Out:
# array([39631.76394397, 41288.69409442, 42945.62424486, 44602.55439531,
#        46259.48454575])
