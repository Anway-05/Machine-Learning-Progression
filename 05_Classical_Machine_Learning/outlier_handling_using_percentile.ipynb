# %%
import pandas as pd

# %%
df=pd.read_csv('AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
a=df['price'].quantile(0.05)

# %%
b=df['price'].quantile(0.95)

# %%
df[df['price']>b]
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 121       27659                   3 Story Town House in Park Slope     119588
# 158       38663                   Luxury Brownstone in Boerum Hill     165789
# ...         ...                                                ...        ...
# 48748  36417250                 US Open special 2-bed luxury condo  133288905
# 48755  36419291  Wyndham Midtown 45 New York City 1 Bedroom Deluxe  273812306
# 48757  36419574     Luxury & Spacious 1500 ft² MANHATTAN Townhouse   11454384
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
# ...

# %%
df[df['price']<a]
# Out:
#              id                                              name    host_id  \
# 36        11452                       Clean and Quiet in Brooklyn       7355
# 249       62452                    A SpeciaL!! Private Room in NY     303939
# 250       62461                       B NYC Staten Alternative...     303939
# 251       62787                       C Private Room By The Ferry     303939
# 256       63320                D Private Che@p Room 2 Explore NYC     303939
# ...         ...                                               ...        ...
# 48851  36455649  #7 New Hotel-Like Private Room KING bed near JFK  263504959
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
# 48867  36473044   The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                      Heaven for you(only for guy)  261338177
# 48871  36475746     A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
#
# ...

# %%
df['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
df['price'].quantile(0.05)
# Out:
# np.float64(40.0)

# %%
df.groupby('room_type')['price'].quantile(0.05)
# Out:
# room_type
# Entire home/apt    78.00
# Private room       37.00
# Shared room        24.95
# Name: price, dtype: float64

# %%
entire_low,private_low,shared_low=df.groupby('room_type')['price'].quantile(0.05)

# %%
df.groupby('room_type')['price'].quantile(0.90)
# Out:
# room_type
# Entire home/apt    347.0
# Private room       131.0
# Shared room        110.0
# Name: price, dtype: float64

# %%
entire_high,private_high,shared_high=df.groupby('room_type')['price'].quantile(0.90)

# %%
df[(df['room_type']=='Entire home/apt') & (df['price']<entire_low)].shape
# Out:
# (1250, 16)

# %%
df[(df['room_type']=='Private room') & (df['price']<private_low)].shape
# Out:
# (1111, 16)

# %%
df[(df['room_type']=='Shared room') & (df['price']<shared_low)].shape
# Out:
# (58, 16)

# %%
df[(df['room_type']=='Entire home/apt') & (df['price']>entire_high)].shape
# Out:
# (2539, 16)

# %%
df[(df['room_type']=='Private room') & (df['price']>private_high)].shape
# Out:
# (2231, 16)

# %%
df[(df['room_type']=='Shared room') & (df['price']>shared_high)].shape
# Out:
# (113, 16)

# %%
1250+1111+58+2539+2231+113
# Out:
# 7302

# %%
df1 = df[
    (
        (df['room_type'] == 'Entire home/apt') &
        (df['price'] > entire_low) &
        (df['price'] < entire_high)
    )
    |
    (
        (df['room_type'] == 'Private room') &
        (df['price'] > private_low) &
        (df['price'] < private_high)
    )
    |
    (
        (df['room_type'] == 'Shared room') &
        (df['price'] > shared_low) &
        (df['price'] < shared_high)
    )
]

# %%
df1.shape
# Out:
# (41426, 16)
